# %% [markdown]
# ![question](img/hw4q4i.png)
# ![question](img/hw4q4ii.png)

# %%
import numpy as np
import pandas as pd
import pyquantlib as pq

from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline

from importlib import reload

# %%
# question assumptions
T, isCall, K, vol, r, q = 0.25, False, 30, 0.3, 0.02, 0.0
pos_o, pos_s, pos_c = 1000, 400, 10000
S_list = [25, 30, 26, 22, 27]
T_incr = 1 / 52

# %%
reload(pq.blackscholes)
df = pq.blackscholes.constant_delta_hedge_port(T, isCall, K, vol, r, q, 
                                               pos_o, pos_s, pos_c,
                                               S_list, T_incr)
df
# Out:
# Calculated full list of T to be [ 0.25        0.23076923  0.21153846  0.19230769  0.17307692]
# -- Starting calcs for week 0 --
# Calculating Option Price and Delta...
# parameters used are: t=0.25, isCall=False, S=25, K=30, vol=0.3, r=0.02, q=0.0
# Result: Price = 5.08836140106, Delta = -0.86588410042
# Starting net delta for the option was -0.86588410042 * 25 * 1000 = -21647.1025105
# Stock Market Values was 25 * 400 = 10000
# The Net Delta = -11647.1025105
# This requires us to trade 465.88410042 shares
# Hedging trades caused the cash amount to go from 10000 -> -1647.1025105
# At the end of the week, the cash amount is compounded by the rf mult 1.00038468936
# This resulted in cash = -1647.73613331
# -- END OF THE WEEK --
#
#
# -- Starting calcs for week 1 --
# Calculating Option Price and Delta...
# parameters used are: t=0.230769230769, isCall=False, S=30, K=30, vol=0.3, r=0.02, q=0.0
# Result: Price = 1.6511607267, Delta = -0.45855162178
# ...
