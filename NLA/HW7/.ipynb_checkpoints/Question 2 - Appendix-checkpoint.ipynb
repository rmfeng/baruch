# %%
import datetime as dt
import numpy as np
import pandas as pd
from scipy.linalg import cho_solve

import matplotlib.pyplot as plt
# %matplotlib inline

lib_path = r'/Users/rmfeng/jupyter/AC-FE/'
import sys
sys.path.append(lib_path)
import acfe_methods as am
import imp_vol_approx as apx

from importlib import reload

# %%
S = 2381.0
val_date = dt.date(2017, 3, 16)
mat_date = dt.date(2017, 9, 29)
T = np.busday_count(val_date, mat_date) / (365.25 * 5/7)
T
# Out:
# 0.54045174537987672

# %%
fn = r"S&P500_ETF_Option_0917.xlsx"
df = pd.read_excel(fn, header=1)[1:]
df.set_index('Strike', inplace=True)
df.rename(columns={
    'Ticker':'c_ticker',
    'Bid':'c_bid',
    'Ask':'c_ask',
    'Volm':'c_volm',
    'Strike.1':'strike',
    'Ticker.1':'p_ticker',
    'Bid.1':'p_bid',
    'Ask.1':'p_ask',
    'Volm.1':'p_volm'
}, inplace=True)
df.head()
# Out:
#                   c_ticker       c_bid       c_ask  c_volm  strike  \
# Strike
# 2150.0  SPXW 9/29/17 C2150  259.299988  260.700012     0.0  2150.0
# 2175.0  SPXW 9/29/17 C2175  238.100006  239.600006     0.0  2175.0
# 2200.0  SPXW 9/29/17 C2200  217.399994  218.899994     0.0  2200.0
# 2225.0  SPXW 9/29/17 C2225  197.199997  198.699997     0.0  2225.0
# 2250.0  SPXW 9/29/17 C2250  177.399994  178.899994     0.0  2250.0
#
#                   p_ticker      p_bid      p_ask  p_volm
# Strike
# 2150.0  SPXW 9/29/17 P2150  34.799999  35.700001    10.0
# 2175.0  SPXW 9/29/17 P2175  38.500000  39.400002    10.0
# 2200.0  SPXW 9/29/17 P2200  42.500000  43.500000    10.0
# 2225.0  SPXW 9/29/17 P2225  47.099998  48.099998     0.0
# 2250.0  SPXW 9/29/17 P2250  52.099998  53.200001     1.0

# %%
df['c_px'] = (df.c_bid + df.c_ask) / 2
df['p_px'] = (df.p_bid + df.p_ask) / 2
df.head()
# Out:
#                   c_ticker       c_bid       c_ask  c_volm  strike  \
# Strike
# 2150.0  SPXW 9/29/17 C2150  259.299988  260.700012     0.0  2150.0
# 2175.0  SPXW 9/29/17 C2175  238.100006  239.600006     0.0  2175.0
# 2200.0  SPXW 9/29/17 C2200  217.399994  218.899994     0.0  2200.0
# 2225.0  SPXW 9/29/17 C2225  197.199997  198.699997     0.0  2225.0
# 2250.0  SPXW 9/29/17 C2250  177.399994  178.899994     0.0  2250.0
#
#                   p_ticker      p_bid      p_ask  p_volm        c_px  \
# Strike
# 2150.0  SPXW 9/29/17 P2150  34.799999  35.700001    10.0  260.000000
# 2175.0  SPXW 9/29/17 P2175  38.500000  39.400002    10.0  238.850006
# 2200.0  SPXW 9/29/17 P2200  42.500000  43.500000    10.0  218.149994
# 2225.0  SPXW 9/29/17 P2225  47.099998  48.099998     0.0  197.949997
# 2250.0  SPXW 9/29/17 P2250  52.099998  53.200001     1.0  178.149994
#
#              p_px
# Strike
# 2150.0  35.250000
# 2175.0  38.950001
# 2200.0  43.000000
# 2225.0  47.599998
# 2250.0  52.650000

# %%
ones = [1] * len(df.strike)
neg_strike = -df.strike.values
A = np.column_stack([ones, neg_strike])

# %%
y = (df.c_px - df.p_px).values.reshape(-1,1)

# %%
AtA = np.matmul(A.transpose(), A)
Aty = np.matmul(A.transpose(), y)
Ut = np.linalg.cholesky(AtA)
x = cho_solve((Ut, True), Aty)
x
# Out:
# array([[  2.36017436e+03],
#        [  9.93169428e-01]])

# %%
PVF = x[0]
disc = x[1]
print(PVF, disc)
# Out:
# [ 2360.17435834] [ 0.99316943]

# %%
q = (-np.log(PVF / S) * (1/T))[0]
q
# Out:
# 0.016255050738693825

# %%
r = (-np.log(disc) * (1/T))[0]
r
# Out:
# 0.012681996986220601

# %% [markdown]
# #### Implied Vols

# %%
df.head()
# Out:
#                   c_ticker       c_bid       c_ask  c_volm  strike  \
# Strike
# 2150.0  SPXW 9/29/17 C2150  259.299988  260.700012     0.0  2150.0
# 2175.0  SPXW 9/29/17 C2175  238.100006  239.600006     0.0  2175.0
# 2200.0  SPXW 9/29/17 C2200  217.399994  218.899994     0.0  2200.0
# 2225.0  SPXW 9/29/17 C2225  197.199997  198.699997     0.0  2225.0
# 2250.0  SPXW 9/29/17 C2250  177.399994  178.899994     0.0  2250.0
#
#                   p_ticker      p_bid      p_ask  p_volm        c_px  \
# Strike
# 2150.0  SPXW 9/29/17 P2150  34.799999  35.700001    10.0  260.000000
# 2175.0  SPXW 9/29/17 P2175  38.500000  39.400002    10.0  238.850006
# 2200.0  SPXW 9/29/17 P2200  42.500000  43.500000    10.0  218.149994
# 2225.0  SPXW 9/29/17 P2225  47.099998  48.099998     0.0  197.949997
# 2250.0  SPXW 9/29/17 P2250  52.099998  53.200001     1.0  178.149994
#
#              p_px
# Strike
# 2150.0  35.250000
# 2175.0  38.950001
# 2200.0  43.000000
# 2225.0  47.599998
# 2250.0  52.650000

# %%
c_ivol_list = np.array([])
p_ivol_list = np.array([])

for row in df.iterrows():
    K = row[1]['strike']
    c_px = row[1]['c_px']
    p_px = row[1]['p_px']
    
    c_ivol = am.imp_vol_newton(c_px, 0.2, T, True, S, K, r, q, am.norm_cdf_def_thresh)
    p_ivol = am.imp_vol_newton(p_px, 0.2, T, False, S, K, r, q, am.norm_cdf_def_thresh)
    
    c_ivol_list = np.append(c_ivol_list, c_ivol)
    p_ivol_list = np.append(p_ivol_list, p_ivol)

df['c_ivol'] = c_ivol_list
df['p_ivol'] = p_ivol_list

# %%
df[['c_ivol','p_ivol']]
# Out:
#           c_ivol    p_ivol
# Strike
# 2150.0  0.173169  0.173398
# 2175.0  0.168303  0.168558
# 2200.0  0.163491  0.163586
# 2225.0  0.158719  0.158758
# 2250.0  0.153714  0.153786
# 2275.0  0.148798  0.148901
# 2300.0  0.143922  0.143975
# 2325.0  0.139030  0.139113
# 2350.0  0.134209  0.134174
# 2375.0  0.129384  0.129380
# 2400.0  0.124624  0.124505
# 2425.0  0.119996  0.119906
# 2450.0  0.115357  0.115296
# 2475.0  0.111125  0.110933
# 2500.0  0.107014  0.106842
# 2550.0  0.099728  0.098597
# 2600.0  0.094662  0.092829
# 2650.0  0.091929  0.093766
# 2700.0  0.091661  0.094497
# 2800.0  0.096657  0.100920

# %% [markdown]
# #### Using paper vol approximator

# %%
df.loc[2150]
# Out:
# c_ticker    SPXW 9/29/17 C2150
# c_bid                    259.3
# c_ask                    260.7
# c_volm                       0
# strike                    2150
# p_ticker    SPXW 9/29/17 P2150
# p_bid                     34.8
# p_ask                     35.7
# p_volm                      10
# c_px                       260
# p_px                     35.25
# c_ivol                0.173169
# p_ivol                0.173398
# Name: 2150.0, dtype: object

# %%
print(S, T, r, q)
# Out:
# 2381.0 0.54045174538 0.0126819969862 0.0162550507387

# %%
c_vol_approx_list = np.array([])
p_vol_approx_list = np.array([])

for row in df.iterrows():
    K = row[1]['strike']
    c_px = row[1]['c_px']
    p_px = row[1]['p_px']
    c_ivol_approx = apx.impvol_approx_call(c_px, K, T, S, r, q)
    p_ivol_approx = apx.impvol_approx_put(p_px, K, T, S, r, q)
    c_vol_approx_list = np.append(c_vol_approx_list, c_ivol_approx)
    p_vol_approx_list = np.append(p_vol_approx_list, p_ivol_approx)

df['c_ivol_approx'] = c_vol_approx_list
df['p_ivol_approx'] = p_vol_approx_list

# %%
df
# Out:
#                   c_ticker       c_bid       c_ask  c_volm  strike  \
# Strike
# 2150.0  SPXW 9/29/17 C2150  259.299988  260.700012     0.0  2150.0
# 2175.0  SPXW 9/29/17 C2175  238.100006  239.600006     0.0  2175.0
# 2200.0  SPXW 9/29/17 C2200  217.399994  218.899994     0.0  2200.0
# 2225.0  SPXW 9/29/17 C2225  197.199997  198.699997     0.0  2225.0
# 2250.0  SPXW 9/29/17 C2250  177.399994  178.899994     0.0  2250.0
# 2275.0  SPXW 9/29/17 C2275  158.300003  159.699997     0.0  2275.0
# 2300.0  SPXW 9/29/17 C2300  139.800003  141.300003     0.0  2300.0
# 2325.0  SPXW 9/29/17 C2325  122.099998  123.599998     0.0  2325.0
# 2350.0  SPXW 9/29/17 C2350  105.300003  106.800003     5.0  2350.0
# 2375.0  SPXW 9/29/17 C2375   89.500000   90.900002     5.0  2375.0
# 2400.0  SPXW 9/29/17 C2400   74.800003   76.099998    12.0  2400.0
# 2425.0  SPXW 9/29/17 C2425   61.299999   62.599998     0.0  2425.0
# 2450.0  SPXW 9/29/17 C2450   49.099998   50.299999     0.0  2450.0
# 2475.0  SPXW 9/29/17 C2475   38.500000   39.599998   370.0  2475.0
# 2500.0  SPXW 9/29/17 C2500   29.400000   30.299999     5.0  2500.0
# 2550.0  SPXW 9/29/17 C2550   15.700000   16.400000    39.0  2550.0
# 2600.0  SPXW 9/29/17 C2600    7.700000    8.200000     2.0  2600.0
# 2650.0  SPXW 9/29/17 C2650    3.600000    4.000000    17.0  2650.0
# 2700.0  SPXW 9/29/17 C2700    1.750000    2.050000    71.0  2700.0
# 2800.0  SPXW 9/29/17 C2800    0.550000    0.750000    10.0  2800.0
#
