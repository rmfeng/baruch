# %%
import pandas as pd
import pandas_datareader.data as web
import datetime as dt

# %%
start = dt.datetime(2010, 1, 1)
end = dt.datetime(2018, 3, 31)

# %%
infl = web.DataReader('BRACPIALLMINMEI', 'fred', start, end)
infl
# Out:
#             BRACPIALLMINMEI
# DATE
# 2010-01-01        97.614896
# 2010-02-01        98.376173
# 2010-03-01        98.887651
# 2010-04-01        99.451464
# 2010-05-01        99.879141
# 2010-06-01        99.879141
# 2010-07-01        99.889094
# 2010-08-01        99.928908
# 2010-09-01       100.378418
# 2010-10-01       101.131346
# 2010-11-01       101.970645
# 2010-12-01       102.613123
# 2011-01-01       103.464944
# 2011-02-01       104.292684
# 2011-03-01       105.116572
# 2011-04-01       105.926010
# 2011-05-01       106.424003
# 2011-06-01       106.583579
# 2011-07-01       106.754071
# 2011-08-01       107.148998
# 2011-09-01       107.716985
# 2011-10-01       108.180302
# 2011-11-01       108.742831
# 2011-12-01       109.285453
# 2012-01-01       109.898713
# 2012-02-01       110.393174
# 2012-03-01       110.624350
# 2012-04-01       111.333934
# 2012-05-01       111.732071
# 2012-06-01       111.821973
# ...                     ...
# 2015-09-01       140.315112
# ...
